# %%
import numpy as np
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
import plotly.express as px
# %matplotlib inline
warnings.filterwarnings('ignore')

# %% [markdown]
# ## **Loading Dataset**

# %%
df = pd.read_csv('dataset/LiwenliangFull.csv')
# Understand the basic information of dataset and the data types involved
df
# Out:
#          Unnamed: 0            max_id              微博id  评论页码  \
# 0                 0  4893821462382076  4467107636950632   1.0
# 1                 1  4893821462382076  4467107636950632   1.0
# 2                 2  4893821462382076  4467107636950632   1.0
# 3                 3  4893821462382076  4467107636950632   1.0
# 4                 4  4893821462382076  4467107636950632   1.0
# ...             ...               ...               ...   ...
# 1423466     1423466  4469128381645556  4467107636950632   NaN
# 1423467     1423467  4469128381645556  4467107636950632   NaN
# 1423468     1423468  4469128381645556  4467107636950632   NaN
# 1423469     1423469  4469128381645556  4467107636950632   NaN
# 1423470     1423470  4469128381645556  4467107636950632   NaN
#
#                      评论id                 评论时间  评论点赞数 评论者IP归属地      评论者姓名  \
# 0        4893834767763833  2023-04-23 23:43:14    0.0     来自广西     W我想撑下去
# 1        4893834284109853  2023-04-23 23:41:19    0.0     来自湖北    一起看日落吧x
# 2        4893833496367362  2023-04-23 23:38:11    0.0     来自四川       薄荷甜绿
# 3        4893832905232325  2023-04-23 23:35:50    0.0     来自法国   我是Liquor
# 4        4893831990086470  2023-04-23 23:32:12    0.0     来自河南     pawyer
# ...                   ...                  ...    ...      ...        ...
# 1423466  4469128385866379  2020-02-07 00:31:42    0.0      NaN    安水果果菓果果
# 1423467  4469128385134746  2020-02-07 00:31:42    0.0      NaN    赌神奔奔918
# 1423468  4469128381647504  2020-02-07 00:31:41    0.0      NaN   奔跑的糯米丸子君
# 1423469  4469128381645557  2020-02-07 00:31:41    0.0      NaN  可弟子有惑依旧愚钝
# 1423470  4469128381651800  2020-02-07 00:31:41    0.0      NaN   Itachi1u
#
#               评论者id 评论者性别  评论者关注数 评论者粉丝数                               评论内容
# 0        5417297741     男      60     63  朋友可以借我一顿饭吗。出门在外找工作遇到困难了，肚子好饿。太艰难了
# 1        5384707935     女      92    332                      李医生 昨天武汉下好大雨哦
# 2        5255030406     女     169     99                             李医生，晚安
# 3        2319895202     女      71     21                       四月底了 下雨还是那么冷
# 4        6072946222     男     884    242                               想起了你
# ...             ...   ...     ...    ...                                ...
# 1423466  2251357683     女     477     88                     全国人民都在守着你，加油！！
# 1423467  5937000680     女     268     39                       加油！我们等你回来🙏🙏🙏
# 1423468  6447681726     女     123     30                   是假的对不对，能不能出来辟谣一下
# 1423469  2812656575     女     455    182                       求求你，加油加油醒过来！
# 1423470  3101281532     女     112   2179                              活下来🙏🏻
#
# [1423471 rows x 14 columns]

# %% [markdown]
# ### **Drop Not Related Column (Based on pre-analysis codebook and NULL value)**

# %%
codebook = pd.read_csv('dataset/codebook.csv')
codebook_not_related = pd.DataFrame(data=codebook['Not Related'].unique(),columns=['code'])
codebook_not_related.dropna(inplace=True)
not_related = codebook_not_related['code'].tolist()
print(not_related) #Not related keywords
# Out:
# ['图片评论', '图片评论  网页链接', '。', '看看', '1', '截图留个爪']

# %%
drop_keywords = df['评论内容'].isin(not_related)
df = df[~drop_keywords]
df = df.dropna(subset='评论内容').reset_index(drop=True)
df
# Out:
#          Unnamed: 0            max_id              微博id  评论页码  \
# 0                 0  4893821462382076  4467107636950632   1.0
# 1                 1  4893821462382076  4467107636950632   1.0
# 2                 2  4893821462382076  4467107636950632   1.0
# 3                 3  4893821462382076  4467107636950632   1.0
# 4                 4  4893821462382076  4467107636950632   1.0
# ...             ...               ...               ...   ...
# 1338078     1423466  4469128381645556  4467107636950632   NaN
# 1338079     1423467  4469128381645556  4467107636950632   NaN
# 1338080     1423468  4469128381645556  4467107636950632   NaN
# 1338081     1423469  4469128381645556  4467107636950632   NaN
# 1338082     1423470  4469128381645556  4467107636950632   NaN
#
#                      评论id                 评论时间  评论点赞数 评论者IP归属地      评论者姓名  \
# 0        4893834767763833  2023-04-23 23:43:14    0.0     来自广西     W我想撑下去
# 1        4893834284109853  2023-04-23 23:41:19    0.0     来自湖北    一起看日落吧x
# 2        4893833496367362  2023-04-23 23:38:11    0.0     来自四川       薄荷甜绿
# 3        4893832905232325  2023-04-23 23:35:50    0.0     来自法国   我是Liquor
# 4        4893831990086470  2023-04-23 23:32:12    0.0     来自河南     pawyer
# ...                   ...                  ...    ...      ...        ...
# 1338078  4469128385866379  2020-02-07 00:31:42    0.0      NaN    安水果果菓果果
# 1338079  4469128385134746  2020-02-07 00:31:42    0.0      NaN    赌神奔奔918
# 1338080  4469128381647504  2020-02-07 00:31:41    0.0      NaN   奔跑的糯米丸子君
# 1338081  4469128381645557  2020-02-07 00:31:41    0.0      NaN  可弟子有惑依旧愚钝
# 1338082  4469128381651800  2020-02-07 00:31:41    0.0      NaN   Itachi1u
#
#               评论者id 评论者性别  评论者关注数 评论者粉丝数                               评论内容
# 0        5417297741     男      60     63  朋友可以借我一顿饭吗。出门在外找工作遇到困难了，肚子好饿。太艰难了
# 1        5384707935     女      92    332                      李医生 昨天武汉下好大雨哦
# 2        5255030406     女     169     99                             李医生，晚安
# 3        2319895202     女      71     21                       四月底了 下雨还是那么冷
# 4        6072946222     男     884    242                               想起了你
# ...             ...   ...     ...    ...                                ...
# 1338078  2251357683     女     477     88                     全国人民都在守着你，加油！！
# 1338079  5937000680     女     268     39                       加油！我们等你回来🙏🙏🙏
# 1338080  6447681726     女     123     30                   是假的对不对，能不能出来辟谣一下
# 1338081  2812656575     女     455    182                       求求你，加油加油醒过来！
# 1338082  3101281532     女     112   2179                              活下来🙏🏻
#
# [1338083 rows x 14 columns]

# %% [markdown]
# ## **Loading the pre-trained model and tokenizer for predicting**

# %%
from transformers import BertTokenizer,BertForSequenceClassification, AdamW, BertConfig, get_linear_schedule_with_warmup

# %%
# 加载 BERT 分词器

model_name_tree_hole = 'model_save/tree_hole'

tokenizer_tree_hole = BertTokenizer.from_pretrained(model_name_tree_hole, do_lower_case=True)
model_tree_hole = BertForSequenceClassification.from_pretrained(
    model_name_tree_hole, # 小写的 12 层预训练模型
    num_labels = 2, # 分类数 --2 表示二分类
                    # 你可以改变这个数字，用于多分类任务  
    output_attentions = False, # 模型是否返回 attentions weights.
    output_hidden_states = False, # 模型是否返回所有隐层状态.
)

model_tree_hole.cuda()
# Out:
# BertForSequenceClassification(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(21232, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (dropout): Dropout(p=0.1, inplace=False)
#   (classifier): Linear(in_features=768, out_features=2, bias=True)
# )

# %%
model_name_whaling_wall = 'model_save/whaling_wall'

tokenizer_whaling_wall = BertTokenizer.from_pretrained(model_name_whaling_wall, do_lower_case=True)
model_whaling_wall = BertForSequenceClassification.from_pretrained(
    model_name_whaling_wall, # 小写的 12 层预训练模型
    num_labels = 2, # 分类数 --2 表示二分类
                    # 你可以改变这个数字，用于多分类任务  
    output_attentions = False, # 模型是否返回 attentions weights.
    output_hidden_states = False, # 模型是否返回所有隐层状态.
)

model_whaling_wall.cuda()
# Out:
# BertForSequenceClassification(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(21216, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (dropout): Dropout(p=0.1, inplace=False)
#   (classifier): Linear(in_features=768, out_features=2, bias=True)
# )

# %%
from transformers import TextClassificationPipeline
pipe_tree_hole = TextClassificationPipeline(model=model_tree_hole, tokenizer=tokenizer_tree_hole,device=0)
pipe_whaling_wall = TextClassificationPipeline(model=model_whaling_wall, tokenizer=tokenizer_whaling_wall,device=0)

# %% [markdown]
# #### **Tree Hole Prediction**

# %%
label_tree_hole = []
sentence_tree_hole = []
rate_tree_hole = []
for i in range(0,len(df['评论内容'])):
    pipelist_tree_hole = pipe_tree_hole(df['评论内容'][i])
    label_tree_hole.append(pipelist_tree_hole[0]['label'])
    sentence_tree_hole.append(df['评论内容'][i])
    rate_tree_hole.append(pipelist_tree_hole[0]['score'])

# %%
df_tree_hole = pd.DataFrame({'sentence':sentence_tree_hole,'Tree Hole':label_tree_hole,'Tree Hole Probability':rate_tree_hole})
df_tree_hole = df_tree_hole.reset_index(drop=True)
df_tree_hole['Tree Hole'].replace({'LABEL_0':'No','LABEL_1':'Yes'},inplace=True)
df_tree_hole.to_csv('dataset/LiwenliangTreeHole.csv',index=False)
display(df_tree_hole.sample(n = 60))
# Out:
#                                                   sentence Tree Hole  \
# 547419                                           一年了……时间真快       Yes
# 351050                                            新年快乐，李医生        No
# 779920                                                 致敬！        No
# 331530                              上天保佑我今天心想事成，渡过这至暗时刻！！！       Yes
# 654099                                 李叔叔，最近是有点多，忙碌起来也挺不错       Yes
# 832783                                  李医生九月了，您离开了我们半年多了，        No
# 455504                           李医生，我刚去打完新冠疫苗，突然想起了你，谢谢你。       Yes
# 239591                                          李医生 我真的好难受       Yes
# 548612                                                 一年了       Yes
# 914021                       今天工作的时候遇到一个和李医生同名同姓的人，但那又怎样呢？       Yes
# 328553                                           你在那边要好好的哦        No
# 1015697                         早，很不想上班还是得去上班，再过五天要发工资了哈哈哈       Yes
# 809916                              中国电力市场建设太他妈难了 政府的人是真不懂       Yes
# 574967                                               李哥 早呀        No
# 555344                                            李医生，活着好累        No
# 558710                                                  晚安       Yes
# 590003                0.997182
# 1303065               0.935708
# 677072                0.991841
# 779965                0.997065
# 480794                0.892981
# 179364                0.991674
# 1123304               0.982264
# 319767                0.714330
# 264067                0.983029
# 607875                0.995905
# 1268749               0.996980
# 200594                0.995981
# 700167                0.990589
# 98109                 0.994204
# 103244                0.996971
# 1037614               0.715112
# 220993                0.617282
# 160736                0.953159
# 648097                0.991962
# 755488                0.994315
# 1080883               0.997069
# 657003                0.958842
# 1167925               0.962465
# 751876                0.996382
# 725647                0.997150
# 636541                0.997224
# 26634                 0.996745
# 423948                0.991944
# 675550                0.990588
# 1234032               0.923592
# 806234                0.885904
# 311975                0.994337
# 1163021               0.738526
# 89947                 0.933619
# 1220461               0.996899
# 572986                0.919844
# 103306                0.970832
# 673084                0.991860
# 126323                0.985383
# 1279742               0.910532
# 463995                0.989338
# 1307023               0.996577
# 472390                0.994423

# %%
df_tree_hole.describe()
# Out:
#        Tree Hole Probability
# count           1.338082e+06
# mean            9.272390e-01
# std             1.197664e-01
# min             5.000004e-01
# 25%             9.241186e-01
# 50%             9.887887e-01
# 75%             9.956762e-01
# max             9.981052e-01

# %% [markdown]
# #### **Whaling Wall Prediction**

# %%
label_whaling_wall = []
sentence_whaling_wall = []
rate_whaling_wall = []
for i in range(0,len(df['评论内容'])):
    pipelist_whaling_wall = pipe_whaling_wall(df['评论内容'][i])
    label_whaling_wall.append(pipelist_whaling_wall[0]['label'])
    sentence_whaling_wall.append(df['评论内容'][i])
    rate_whaling_wall.append(pipelist_whaling_wall[0]['score'])

# %%
df_whaling_wall = pd.DataFrame({'sentence':sentence_whaling_wall,'Whaling Wall':label_whaling_wall,'Whaling Wall Probability':rate_whaling_wall})
df_whaling_wall = df_whaling_wall.reset_index(drop=True)
df_whaling_wall['Whaling Wall'].replace({'LABEL_0':'No','LABEL_1':'Yes'},inplace=True)
df_whaling_wall.to_csv('dataset/LiwenliangWhalingWall.csv',index=False)
display(df_whaling_wall.sample(n = 60))
# Out:
#                                                   sentence Whaling Wall  \
# 218711                                           李医生新冠还在继续          Yes
# 1257458                                          谢谢您 温暖的人啊          Yes
# 94160                      李医生今年我可以上岸吗，真的好迷茫还有16天了，感觉没有动力了           No
# 45311    李医生，今天是2022年的最后一天啦，2022年糟糕透了，开放以后周围的人都阳了，希望202...          Yes
# 982371   奶奶还是走了 看到她后来每天被病痛一点点折磨消瘦痛苦的样子让我想起小时候上学每天中午在她那吃...           No
# 841086                                 在你这受的委屈也不少了，今天算啥委屈啊           No
# 237344                                             什么时候来呢？           No
# 40725                                                李医生晚安          Yes
# 207089                                               晚安 亮哥          Yes
# 511934         李医生，我不知道四月该怎么过，感觉心好累，学业压力好大。感觉好自卑，因为自己能力好差。           No
# 391527                                   早上好李醫生 今天要從青島回北京啦          Yes
# 53931                                              但渾身還是很痛           No
# 250054                                           一切都会好起来的！           No
# 205073                                三妹是个中元人，对于，看不见的，比较在行           No
# 247077                                               聚散终有时           No
#
#          Whaling Wall Probability
# 218711                   0.873920
# 1257458                  0.987499
# 94160                    0.654166
# 45311                    0.842550
# 982371                   0.934978
# 841086                   0.761556
# 237344                   0.836189
# 40725                    0.996099
# 207089                   0.996100
# 511934                   0.684286
# 391527                   0.969510
# 53931                    0.988158
# 250054                   0.709249
# 205073                   0.988036
# 978256                   0.967539
# 807493                   0.996683
# 495986                   0.905464
# 493975                   0.995403
# 821780                   0.996640
# 850354                   0.997734
# 338155                   0.975298
# 110612                   0.990620
# 247549                   0.988915
# 269732                   0.970820
# 387143                   0.978328
# 688661                   0.996987
# 1149169                  0.992190
# 1192520                  0.997082
# 450354                   0.993360
# 378450                   0.505836
# 150409                   0.996992
# 970011                   0.991807
# 1202488                  0.995463
# 1167899                  0.995305
# 1003194                  0.996137
# 668091                   0.980428
# 704901                   0.855358
# 1178986                  0.637735
# 843961                   0.577494
# 861598                   0.991027
# 454222                   0.994808
# 86445                    0.996612
# 880775                   0.996345
# 7399                     0.983412
# 779663                   0.995656
# 925990                   0.996564
# 1277364                  0.996038
# 140341                   0.995895
# 1191902                  0.838806
# 400945                   0.975607
# 1022372                  0.821883
# 787531                   0.996564
# 472208                   0.995262
# 23901                    0.628502
# 859867                   0.934183
# 763233                   0.996059
# 529016                   0.991098
# 1258674                  0.936436
# 133019                   0.997080
# 247077                   0.979397

# %%
df_whaling_wall.describe()
# Out:
#        Whaling Wall Probability
# count              1.338082e+06
# mean               9.273308e-01
# std                1.261127e-01
# min                5.000005e-01
# 25%                9.364046e-01
# 50%                9.908584e-01
# 75%                9.953676e-01
# max                9.985570e-01

# %% [markdown]
# ## **Merging Resullt**

# %%
df = df.drop('Unnamed: 0',axis=1)
df.rename(columns={'评论内容':'sentence'},inplace=True)

# %%
df_tree_hole.index = df_tree_hole.index+1
df_whaling_wall.index = df_whaling_wall.index+1

# %%
dfmarked = pd.concat([df,df_tree_hole,df_whaling_wall],axis=1)
dfmarked
# Out:
#                    max_id              微博id  评论页码              评论id  \
# 0        4893821462382076  4467107636950632   1.0  4893834767763833
# 1        4893821462382076  4467107636950632   1.0  4893834284109853
# 2        4893821462382076  4467107636950632   1.0  4893833496367362
# 3        4893821462382076  4467107636950632   1.0  4893832905232325
# 4        4893821462382076  4467107636950632   1.0  4893831990086470
# ...                   ...               ...   ...               ...
# 1338078  4469128381645556  4467107636950632   NaN  4469128385866379
# 1338079  4469128381645556  4467107636950632   NaN  4469128385134746
# 1338080  4469128381645556  4467107636950632   NaN  4469128381647504
# 1338081  4469128381645556  4467107636950632   NaN  4469128381645557
# 1338082  4469128381645556  4467107636950632   NaN  4469128381651800
#
#                         评论时间  评论点赞数 评论者IP归属地      评论者姓名       评论者id 评论者性别  \
# 0        2023-04-23 23:43:14    0.0     来自广西     W我想撑下去  5417297741     男
# 1        2023-04-23 23:41:19    0.0     来自湖北    一起看日落吧x  5384707935     女
# 2        2023-04-23 23:38:11    0.0     来自四川       薄荷甜绿  5255030406     女
# 3        2023-04-23 23:35:50    0.0     来自法国   我是Liquor  2319895202     女
# 4        2023-04-23 23:32:12    0.0     来自河南     pawyer  6072946222     男
# ...                      ...    ...      ...        ...         ...   ...
# 1338078  2020-02-07 00:31:42    0.0      NaN    安水果果菓果果  2251357683     女
# 1338079  2020-02-07 00:31:42    0.0      NaN    赌神奔奔918  5937000680     女
# 1338080  2020-02-07 00:31:41    0.0      NaN   奔跑的糯米丸子君  6447681726     女
# 1338081  2020-02-07 00:31:41    0.0      NaN  可弟子有惑依旧愚钝  2812656575     女
# 1338082  2020-02-07 00:31:41    0.0      NaN   Itachi1u  3101281532     女
#
#          评论者关注数 评论者粉丝数                           sentence          sentence  \
# 0            60     63  朋友可以借我一顿饭吗。出门在外找工作遇到困难了，肚子好饿。太艰难了               NaN
# 1            92    332                      李医生 昨天武汉下好大雨哦     李医生 昨天武汉下好大雨哦
# 2           169     99                             李医生，晚安            李医生，晚安
# 3            71     21                       四月底了 下雨还是那么冷      四月底了 下雨还是那么冷
# 4           884    242                               想起了你              想起了你
# ...         ...    ...                                ...               ...
# 1338078     477     88                     全国人民都在守着你，加油！！    全国人民都在守着你，加油！！
# 1338079     268     39                       加油！我们等你回来🙏🙏🙏      加油！我们等你回来🙏🙏🙏
# 1338080     123     30                   是假的对不对，能不能出来辟谣一下  是假的对不对，能不能出来辟谣一下
# 1338081     455    182                       求求你，加油加油醒过来！      求求你，加油加油醒过来！
# 1338082     112   2179                              活下来🙏🏻             活下来🙏🏻
#
#         Tree Hole  Tree Hole Probability          sentence Whaling Wall  \
# 0             NaN                    NaN               NaN          NaN
# 1             Yes               0.941288     李医生 昨天武汉下好大雨哦          Yes
# 2              No               0.996930            李医生，晚安          Yes
# 3             Yes               0.987697      四月底了 下雨还是那么冷           No
# 4              No               0.995238              想起了你          Yes
# ...           ...                    ...               ...          ...
# 1338078        No               0.983879    全国人民都在守着你，加油！！          Yes
# 1338079        No               0.993155      加油！我们等你回来🙏🙏🙏          Yes
# 1338080        No               0.546834  是假的对不对，能不能出来辟谣一下           No
# 1338081        No               0.988626      求求你，加油加油醒过来！          Yes
# 1338082        No               0.862130             活下来🙏🏻          Yes
#
#          Whaling Wall Probability
# 0                             NaN
# 1                        0.695900
# 2                        0.996329
# 3                        0.993291
# 4                        0.991719
# ...                           ...
# 1338078                  0.996354
# 1338079                  0.993806
# 1338080                  0.965628
# 1338081                  0.996677
# 1338082                  0.940727
#
# [1338083 rows x 19 columns]

# %% [markdown]
# ## **Output**

# %%
dfmarked = dfmarked.drop('max_id',axis=1)
dfmarked = dfmarked.drop('微博id',axis=1)
dfmarked = dfmarked.drop('评论页码',axis=1)
dfmarked.columns = ['Comment_id','Comment_Time','Comment_Like','Commnet_IP','Commenter_Name','Commenter_id','Commenter_gender','Commenter_Following',
                    'Commenter_Follower','Comments','sentence','Tree Hole','Tree Hole Probability','sentence','Whaling Wall','Whaling Wall Probability']
dfmarked = dfmarked.drop('sentence',axis=1)
dfmarked.to_csv('dataset/LiwenliangMarked.csv',index=False)

# %%
dfmarked = pd.read_csv('dataset/LiwenliangMarked.csv')
dfmarked
# Out:
#                Comment_id         Comment_Time  Comment_Like Commnet_IP  \
# 0        4893834767763833  2023-04-23 23:43:14           0.0       来自广西
# 1        4893834284109853  2023-04-23 23:41:19           0.0       来自湖北
# 2        4893833496367362  2023-04-23 23:38:11           0.0       来自四川
# 3        4893832905232325  2023-04-23 23:35:50           0.0       来自法国
# 4        4893831990086470  2023-04-23 23:32:12           0.0       来自河南
# ...                   ...                  ...           ...        ...
# 1338078  4469128385866379  2020-02-07 00:31:42           0.0        NaN
# 1338079  4469128385134746  2020-02-07 00:31:42           0.0        NaN
# 1338080  4469128381647504  2020-02-07 00:31:41           0.0        NaN
# 1338081  4469128381645557  2020-02-07 00:31:41           0.0        NaN
# 1338082  4469128381651800  2020-02-07 00:31:41           0.0        NaN
#
#         Commenter_Name  Commenter_id Commenter_gender  Commenter_Following  \
# 0               W我想撑下去    5417297741                男                   60
# 1              一起看日落吧x    5384707935                女                   92
# 2                 薄荷甜绿    5255030406                女                  169
# 3             我是Liquor    2319895202                女                   71
# 4               pawyer    6072946222                男                  884
# ...                ...           ...              ...                  ...
# 1338078        安水果果菓果果    2251357683                女                  477
# 1338079        赌神奔奔918    5937000680                女                  268
# 1338080       奔跑的糯米丸子君    6447681726                女                  123
# 1338081      可弟子有惑依旧愚钝    2812656575                女                  455
# 1338082       Itachi1u    3101281532                女                  112
#
#         Commenter_Follower                           Comments Tree Hole  \
# 0                       63  朋友可以借我一顿饭吗。出门在外找工作遇到困难了，肚子好饿。太艰难了       Yes
# 1                      332                      李医生 昨天武汉下好大雨哦       Yes
# 2                       99                             李医生，晚安        No
# 3                       21                       四月底了 下雨还是那么冷       Yes
# 4                      242                               想起了你        No
# ...                    ...                                ...       ...
# 1338078                 88                     全国人民都在守着你，加油！！        No
# 1338079                 39                       加油！我们等你回来🙏🙏🙏        No
# 1338080                 30                   是假的对不对，能不能出来辟谣一下        No
# 1338081                182                       求求你，加油加油醒过来！        No
# 1338082               2179                              活下来🙏🏻        No
#
#          Tree Hole Probability Whaling Wall  Whaling Wall Probability
# 0                     0.996692           No                  0.993389
# 1                     0.941288          Yes                  0.695900
# 2                     0.996930          Yes                  0.996329
# 3                     0.987697           No                  0.993291
# 4                     0.995238          Yes                  0.991719
# ...                        ...          ...                       ...
# 1338078               0.983879          Yes                  0.996354
# 1338079               0.993155          Yes                  0.993806
# 1338080               0.546834           No                  0.965628
# 1338081               0.988626          Yes                  0.996677
# 1338082               0.862130          Yes                  0.940727
#
# [1338083 rows x 14 columns]
