# %%
import pandas as pd

# %%
df = pd.read_csv('dataset/LiwenliangComments_Split.csv')
df['Comment_Time'] = pd.to_datetime(df['Comment_Time'], format='%Y-%m-%d %H:%M:%S')
df['Comment_Day'] = df['Comment_Time'].dt.date
df
# Out:
# C:\Users\kidul\AppData\Local\Temp\ipykernel_43380\2589811621.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('dataset/LiwenliangComments_Split.csv')
#                Comment_id        Comment_Time  Comment_Like Commnet_IP  \
# 0        4893834767763833 2023-04-23 23:43:14           0.0       来自广西
# 1        4893834284109853 2023-04-23 23:41:19           0.0       来自湖北
# 2        4893833496367362 2023-04-23 23:38:11           0.0       来自四川
# 3        4893832905232325 2023-04-23 23:35:50           0.0       来自法国
# 4        4893831990086470 2023-04-23 23:32:12           0.0       来自河南
# ...                   ...                 ...           ...        ...
# 1338078  4469128385866379 2020-02-07 00:31:42           0.0        NaN
# 1338079  4469128385134746 2020-02-07 00:31:42           0.0        NaN
# 1338080  4469128381647504 2020-02-07 00:31:41           0.0        NaN
# ...

# %%
df['Comment_Like'].describe()
# Out:
# count    1.337892e+06
# mean     9.868098e-01
# std      3.959707e+00
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      1.000000e+00
# max      1.475000e+03
# Name: Comment_Like, dtype: float64

# %%
pd.set_option('display.max_colwidth', 400)
df['Comment_Day'] = pd.to_datetime(df['Comment_Day'], format='%Y-%m-%d')
df_temping = df[df['Comment_Day'] == '2022-09-19']
df_temping = df_temping.sort_values(by=['Comment_Like'],ascending=False)
head = df_temping['Comments'].head(20)
like = df_temping['Comment_Like'].head(20)
headlike = pd.concat([head,like],axis=1)
headlike
# Out:
#                                                                                                                                              Comments  \
# 178622                                                                                         最近后背一直痒，但是伸手却摸不到东西，去医院检查却查不到什么东西。晚上照镜子的时候竟然若隐若现的看见一条辫子
# 178588                                                                                                             三年前，他们因为无知让百姓买单；三年后，他们因为乌纱帽继续让百姓买单
# 178661                                                                                                                   三年前他们不承认它来了，三年后他们不承认它走了……rip
# 177677                                                                                                        李医生，贵州的翻车事故，在今天的人民日报上，只占据了第八版右下角的一小块地方。
# 179439                                                                                   李医生你好，真没想到，你死的那一年，是往后最好的一年。病毒已然成了他们的财神，老百姓只是他们发财的供体，吃人的时代来了。
# ...
